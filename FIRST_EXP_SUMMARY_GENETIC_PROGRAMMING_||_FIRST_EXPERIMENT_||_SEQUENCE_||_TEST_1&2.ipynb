# %% [markdown]
# <a href="https://colab.research.google.com/github/javiagu13/DataAnalysisOfGeneticProgramming/blob/main/FIRST_EXP_SUMMARY_GENETIC_PROGRAMMING_%7C%7C_FIRST_EXPERIMENT_%7C%7C_SEQUENCE_%7C%7C_TEST_1%262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title  { vertical-output: true }
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import scipy.stats as stats
import os
dataCUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/CUT.csv")
dataCUTmatrix=dataCUT.to_numpy()

dataINFARO = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INFARO.csv")
dataINFAROmatrix =dataINFARO.to_numpy()

dataINFAROUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INFAROUP.csv")
dataINFAROUPmatrix =dataINFAROUP.to_numpy()

dataOUTFARO = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/OUTFARO.csv")
dataOUTFAROmatrix =dataOUTFARO.to_numpy()

dataOUTFAROUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INFAROUP.csv")
dataOUTFAROUPmatrix =dataOUTFAROUP.to_numpy()

dataPEAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/PEAL.csv")
dataPEALmatrix =dataPEAL.to_numpy()

dataPEALUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/PEALUP.csv")
dataPEALUPmatrix =dataPEALUP.to_numpy()

dataSLIPCUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/SLIPCUT.csv")
dataSLIPCUTmatrix =dataSLIPCUT.to_numpy()

dataSLIPCUTUP= pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/SLIPCUTUP.csv")
dataSLIPCUTUPmatrix =dataSLIPCUTUP.to_numpy()


y = np.arange(start=1, stop=151, step=1)

# %%
#@title
zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,0]
bCUT=dataCUTmatrix[:,1]
cCUT=dataCUTmatrix[:,2]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,0]
bINFARO=dataINFAROmatrix[:,1]
cINFARO=dataINFAROmatrix[:,2]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,0]
bINFAROUP=dataINFAROUPmatrix[:,1]
cINFAROUP=dataINFAROUPmatrix[:,2]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,0]
bOUTFARO=dataOUTFAROmatrix[:,1]
cOUTFARO=dataOUTFAROmatrix[:,2]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,0]
bOUTFAROUP=dataOUTFAROUPmatrix[:,1]
cOUTFAROUP=dataOUTFAROUPmatrix[:,2]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,0]
bPEAL=dataPEALmatrix[:,1]
cPEAL=dataPEALmatrix[:,2]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,0]
bPEALUP=dataPEALUPmatrix[:,1]
cPEALUP=dataPEALUPmatrix[:,2]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,0]
bSLIPCUT=dataSLIPCUTmatrix[:,1]
cSLIPCUT=dataSLIPCUTmatrix[:,2]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,0]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,1]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,2]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=2 || "SEQUENCE METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,3]
bCUT=dataCUTmatrix[:,4]
cCUT=dataCUTmatrix[:,5]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,3]
bINFARO=dataINFAROmatrix[:,4]
cINFARO=dataINFAROmatrix[:,5]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,3]
bINFAROUP=dataINFAROUPmatrix[:,4]
cINFAROUP=dataINFAROUPmatrix[:,5]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,3]
bOUTFARO=dataOUTFAROmatrix[:,4]
cOUTFARO=dataOUTFAROmatrix[:,5]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,3]
bOUTFAROUP=dataOUTFAROUPmatrix[:,4]
cOUTFAROUP=dataOUTFAROUPmatrix[:,5]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,3]
bPEAL=dataPEALmatrix[:,4]
cPEAL=dataPEALmatrix[:,5]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,3]
bPEALUP=dataPEALUPmatrix[:,4]
cPEALUP=dataPEALUPmatrix[:,5]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,3]
bSLIPCUT=dataSLIPCUTmatrix[:,4]
cSLIPCUT=dataSLIPCUTmatrix[:,5]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,3]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,4]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,5]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=4 || "SEQUENCE METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,6]
bCUT=dataCUTmatrix[:,7]
cCUT=dataCUTmatrix[:,8]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,6]
bINFARO=dataINFAROmatrix[:,7]
cINFARO=dataINFAROmatrix[:,8]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,6]
bINFAROUP=dataINFAROUPmatrix[:,7]
cINFAROUP=dataINFAROUPmatrix[:,8]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,6]
bOUTFARO=dataOUTFAROmatrix[:,7]
cOUTFARO=dataOUTFAROmatrix[:,8]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,6]
bOUTFAROUP=dataOUTFAROUPmatrix[:,7]
cOUTFAROUP=dataOUTFAROUPmatrix[:,8]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,6]
bPEAL=dataPEALmatrix[:,7]
cPEAL=dataPEALmatrix[:,8]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,6]
bPEALUP=dataPEALUPmatrix[:,7]
cPEALUP=dataPEALUPmatrix[:,8]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,6]
bSLIPCUT=dataSLIPCUTmatrix[:,7]
cSLIPCUT=dataSLIPCUTmatrix[:,8]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,6]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,7]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,8]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=8 || "SEQUENCE METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,9]
bCUT=dataCUTmatrix[:,10]
cCUT=dataCUTmatrix[:,11]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,9]
bINFARO=dataINFAROmatrix[:,10]
cINFARO=dataINFAROmatrix[:,11]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,9]
bINFAROUP=dataINFAROUPmatrix[:,10]
cINFAROUP=dataINFAROUPmatrix[:,11]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,9]
bOUTFARO=dataOUTFAROmatrix[:,10]
cOUTFARO=dataOUTFAROmatrix[:,11]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,9]
bOUTFAROUP=dataOUTFAROUPmatrix[:,10]
cOUTFAROUP=dataOUTFAROUPmatrix[:,11]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,9]
bPEAL=dataPEALmatrix[:,10]
cPEAL=dataPEALmatrix[:,11]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,9]
bPEALUP=dataPEALUPmatrix[:,10]
cPEALUP=dataPEALUPmatrix[:,11]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,9]
bSLIPCUT=dataSLIPCUTmatrix[:,10]
cSLIPCUT=dataSLIPCUTmatrix[:,11]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,9]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,10]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,11]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=16 || "SEQUENCE METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()


zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,12]
bCUT=dataCUTmatrix[:,13]
cCUT=dataCUTmatrix[:,14]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,12]
bINFARO=dataINFAROmatrix[:,13]
cINFARO=dataINFAROmatrix[:,14]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,12]
bINFAROUP=dataINFAROUPmatrix[:,13]
cINFAROUP=dataINFAROUPmatrix[:,14]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,12]
bOUTFARO=dataOUTFAROmatrix[:,13]
cOUTFARO=dataOUTFAROmatrix[:,14]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,12]
bOUTFAROUP=dataOUTFAROUPmatrix[:,13]
cOUTFAROUP=dataOUTFAROUPmatrix[:,14]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,12]
bPEAL=dataPEALmatrix[:,13]
cPEAL=dataPEALmatrix[:,14]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,12]
bPEALUP=dataPEALUPmatrix[:,13]
cPEALUP=dataPEALUPmatrix[:,14]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,12]
bSLIPCUT=dataSLIPCUTmatrix[:,13]
cSLIPCUT=dataSLIPCUTmatrix[:,14]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,12]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,13]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,14]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=32 || "SEQUENCE METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()

# %%
#@title
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import scipy.stats as stats
import os
dataCUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/CUT.csv")
dataCUTmatrix=dataCUT.to_numpy()

dataINFARO = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INFARO.csv")
dataINFAROmatrix =dataINFARO.to_numpy()

dataINFAROUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INFAROUP.csv")
dataINFAROUPmatrix =dataINFAROUP.to_numpy()

dataOUTFARO = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/OUTFARO.csv")
dataOUTFAROmatrix =dataOUTFARO.to_numpy()

dataOUTFAROUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INFAROUP.csv")
dataOUTFAROUPmatrix =dataOUTFAROUP.to_numpy()

dataPEAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/PEAL.csv")
dataPEALmatrix =dataPEAL.to_numpy()

dataPEALUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/PEALUP.csv")
dataPEALUPmatrix =dataPEALUP.to_numpy()

dataSLIPCUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/SLIPCUT.csv")
dataSLIPCUTmatrix =dataSLIPCUT.to_numpy()

dataSLIPCUTUP= pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/SLIPCUTUP.csv")
dataSLIPCUTUPmatrix =dataSLIPCUTUP.to_numpy()

# %%
#@title
zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,0]
bCUT=dataCUTmatrix[:,1]
cCUT=dataCUTmatrix[:,2]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,0]
bINFARO=dataINFAROmatrix[:,1]
cINFARO=dataINFAROmatrix[:,2]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,0]
bINFAROUP=dataINFAROUPmatrix[:,1]
cINFAROUP=dataINFAROUPmatrix[:,2]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,0]
bOUTFARO=dataOUTFAROmatrix[:,1]
cOUTFARO=dataOUTFAROmatrix[:,2]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,0]
bOUTFAROUP=dataOUTFAROUPmatrix[:,1]
cOUTFAROUP=dataOUTFAROUPmatrix[:,2]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,0]
bPEAL=dataPEALmatrix[:,1]
cPEAL=dataPEALmatrix[:,2]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,0]
bPEALUP=dataPEALUPmatrix[:,1]
cPEALUP=dataPEALUPmatrix[:,2]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,0]
bSLIPCUT=dataSLIPCUTmatrix[:,1]
cSLIPCUT=dataSLIPCUTmatrix[:,2]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,0]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,1]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,2]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=2 || "HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,3]
bCUT=dataCUTmatrix[:,4]
cCUT=dataCUTmatrix[:,5]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,3]
bINFARO=dataINFAROmatrix[:,4]
cINFARO=dataINFAROmatrix[:,5]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,3]
bINFAROUP=dataINFAROUPmatrix[:,4]
cINFAROUP=dataINFAROUPmatrix[:,5]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,3]
bOUTFARO=dataOUTFAROmatrix[:,4]
cOUTFARO=dataOUTFAROmatrix[:,5]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,3]
bOUTFAROUP=dataOUTFAROUPmatrix[:,4]
cOUTFAROUP=dataOUTFAROUPmatrix[:,5]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,3]
bPEAL=dataPEALmatrix[:,4]
cPEAL=dataPEALmatrix[:,5]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,3]
bPEALUP=dataPEALUPmatrix[:,4]
cPEALUP=dataPEALUPmatrix[:,5]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,3]
bSLIPCUT=dataSLIPCUTmatrix[:,4]
cSLIPCUT=dataSLIPCUTmatrix[:,5]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,3]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,4]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,5]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=4 || "HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,6]
bCUT=dataCUTmatrix[:,7]
cCUT=dataCUTmatrix[:,8]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,6]
bINFARO=dataINFAROmatrix[:,7]
cINFARO=dataINFAROmatrix[:,8]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,6]
bINFAROUP=dataINFAROUPmatrix[:,7]
cINFAROUP=dataINFAROUPmatrix[:,8]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,6]
bOUTFARO=dataOUTFAROmatrix[:,7]
cOUTFARO=dataOUTFAROmatrix[:,8]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,6]
bOUTFAROUP=dataOUTFAROUPmatrix[:,7]
cOUTFAROUP=dataOUTFAROUPmatrix[:,8]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,6]
bPEAL=dataPEALmatrix[:,7]
cPEAL=dataPEALmatrix[:,8]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,6]
bPEALUP=dataPEALUPmatrix[:,7]
cPEALUP=dataPEALUPmatrix[:,8]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,6]
bSLIPCUT=dataSLIPCUTmatrix[:,7]
cSLIPCUT=dataSLIPCUTmatrix[:,8]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,6]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,7]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,8]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=8 || "HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,9]
bCUT=dataCUTmatrix[:,10]
cCUT=dataCUTmatrix[:,11]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,9]
bINFARO=dataINFAROmatrix[:,10]
cINFARO=dataINFAROmatrix[:,11]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,9]
bINFAROUP=dataINFAROUPmatrix[:,10]
cINFAROUP=dataINFAROUPmatrix[:,11]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,9]
bOUTFARO=dataOUTFAROmatrix[:,10]
cOUTFARO=dataOUTFAROmatrix[:,11]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,9]
bOUTFAROUP=dataOUTFAROUPmatrix[:,10]
cOUTFAROUP=dataOUTFAROUPmatrix[:,11]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,9]
bPEAL=dataPEALmatrix[:,10]
cPEAL=dataPEALmatrix[:,11]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,9]
bPEALUP=dataPEALUPmatrix[:,10]
cPEALUP=dataPEALUPmatrix[:,11]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,9]
bSLIPCUT=dataSLIPCUTmatrix[:,10]
cSLIPCUT=dataSLIPCUTmatrix[:,11]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,9]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,10]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,11]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=16 || "HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()


zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,12]
bCUT=dataCUTmatrix[:,13]
cCUT=dataCUTmatrix[:,14]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,12]
bINFARO=dataINFAROmatrix[:,13]
cINFARO=dataINFAROmatrix[:,14]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,12]
bINFAROUP=dataINFAROUPmatrix[:,13]
cINFAROUP=dataINFAROUPmatrix[:,14]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,12]
bOUTFARO=dataOUTFAROmatrix[:,13]
cOUTFARO=dataOUTFAROmatrix[:,14]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,12]
bOUTFAROUP=dataOUTFAROUPmatrix[:,13]
cOUTFAROUP=dataOUTFAROUPmatrix[:,14]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,12]
bPEAL=dataPEALmatrix[:,13]
cPEAL=dataPEALmatrix[:,14]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,12]
bPEALUP=dataPEALUPmatrix[:,13]
cPEALUP=dataPEALUPmatrix[:,14]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,12]
bSLIPCUT=dataSLIPCUTmatrix[:,13]
cSLIPCUT=dataSLIPCUTmatrix[:,14]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,12]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,13]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,14]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=32 || "HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()

# %%
#@title  { display-mode: "code" }
dataCUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/CUT.csv")
dataCUTmatrix=dataCUT.to_numpy()

dataINFARO = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INFARO.csv")
dataINFAROmatrix =dataINFARO.to_numpy()

dataINFAROUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INFAROUP.csv")
dataINFAROUPmatrix =dataINFAROUP.to_numpy()

dataOUTFARO = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/OUTFARO.csv")
dataOUTFAROmatrix =dataOUTFARO.to_numpy()

dataOUTFAROUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INFAROUP.csv")
dataOUTFAROUPmatrix =dataOUTFAROUP.to_numpy()

dataPEAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/PEAL.csv")
dataPEALmatrix =dataPEAL.to_numpy()

dataPEALUP = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/PEALUP.csv")
dataPEALUPmatrix =dataPEALUP.to_numpy()

dataSLIPCUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/SLIPCUT.csv")
dataSLIPCUTmatrix =dataSLIPCUT.to_numpy()

dataSLIPCUTUP= pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/SLIPCUTUP.csv")
dataSLIPCUTUPmatrix =dataSLIPCUTUP.to_numpy()

# %%
#@title
zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,0]
bCUT=dataCUTmatrix[:,1]
cCUT=dataCUTmatrix[:,2]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,0]
bINFARO=dataINFAROmatrix[:,1]
cINFARO=dataINFAROmatrix[:,2]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,0]
bINFAROUP=dataINFAROUPmatrix[:,1]
cINFAROUP=dataINFAROUPmatrix[:,2]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,0]
bOUTFARO=dataOUTFAROmatrix[:,1]
cOUTFARO=dataOUTFAROmatrix[:,2]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,0]
bOUTFAROUP=dataOUTFAROUPmatrix[:,1]
cOUTFAROUP=dataOUTFAROUPmatrix[:,2]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,0]
bPEAL=dataPEALmatrix[:,1]
cPEAL=dataPEALmatrix[:,2]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,0]
bPEALUP=dataPEALUPmatrix[:,1]
cPEALUP=dataPEALUPmatrix[:,2]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,0]
bSLIPCUT=dataSLIPCUTmatrix[:,1]
cSLIPCUT=dataSLIPCUTmatrix[:,2]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,0]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,1]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,2]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=2 || "SEQUENCE-HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,3]
bCUT=dataCUTmatrix[:,4]
cCUT=dataCUTmatrix[:,5]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,3]
bINFARO=dataINFAROmatrix[:,4]
cINFARO=dataINFAROmatrix[:,5]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,3]
bINFAROUP=dataINFAROUPmatrix[:,4]
cINFAROUP=dataINFAROUPmatrix[:,5]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,3]
bOUTFARO=dataOUTFAROmatrix[:,4]
cOUTFARO=dataOUTFAROmatrix[:,5]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,3]
bOUTFAROUP=dataOUTFAROUPmatrix[:,4]
cOUTFAROUP=dataOUTFAROUPmatrix[:,5]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,3]
bPEAL=dataPEALmatrix[:,4]
cPEAL=dataPEALmatrix[:,5]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,3]
bPEALUP=dataPEALUPmatrix[:,4]
cPEALUP=dataPEALUPmatrix[:,5]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,3]
bSLIPCUT=dataSLIPCUTmatrix[:,4]
cSLIPCUT=dataSLIPCUTmatrix[:,5]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,3]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,4]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,5]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=4 || "SEQUENCE-HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,6]
bCUT=dataCUTmatrix[:,7]
cCUT=dataCUTmatrix[:,8]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,6]
bINFARO=dataINFAROmatrix[:,7]
cINFARO=dataINFAROmatrix[:,8]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,6]
bINFAROUP=dataINFAROUPmatrix[:,7]
cINFAROUP=dataINFAROUPmatrix[:,8]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,6]
bOUTFARO=dataOUTFAROmatrix[:,7]
cOUTFARO=dataOUTFAROmatrix[:,8]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,6]
bOUTFAROUP=dataOUTFAROUPmatrix[:,7]
cOUTFAROUP=dataOUTFAROUPmatrix[:,8]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,6]
bPEAL=dataPEALmatrix[:,7]
cPEAL=dataPEALmatrix[:,8]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,6]
bPEALUP=dataPEALUPmatrix[:,7]
cPEALUP=dataPEALUPmatrix[:,8]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,6]
bSLIPCUT=dataSLIPCUTmatrix[:,7]
cSLIPCUT=dataSLIPCUTmatrix[:,8]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,6]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,7]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,8]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=8 || "SEQUENCE-HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()




zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,9]
bCUT=dataCUTmatrix[:,10]
cCUT=dataCUTmatrix[:,11]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,9]
bINFARO=dataINFAROmatrix[:,10]
cINFARO=dataINFAROmatrix[:,11]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,9]
bINFAROUP=dataINFAROUPmatrix[:,10]
cINFAROUP=dataINFAROUPmatrix[:,11]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,9]
bOUTFARO=dataOUTFAROmatrix[:,10]
cOUTFARO=dataOUTFAROmatrix[:,11]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,9]
bOUTFAROUP=dataOUTFAROUPmatrix[:,10]
cOUTFAROUP=dataOUTFAROUPmatrix[:,11]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,9]
bPEAL=dataPEALmatrix[:,10]
cPEAL=dataPEALmatrix[:,11]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,9]
bPEALUP=dataPEALUPmatrix[:,10]
cPEALUP=dataPEALUPmatrix[:,11]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,9]
bSLIPCUT=dataSLIPCUTmatrix[:,10]
cSLIPCUT=dataSLIPCUTmatrix[:,11]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,9]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,10]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,11]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=16 || "SEQUENCE-HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()


zCUT=np.empty(150,dtype=int)
zINFARO=np.empty(150,dtype=int)
zINFAROUP=np.empty(150,dtype=int)
zOUTFARO=np.empty(150,dtype=int)
zOUTFAROUP=np.empty(150,dtype=int)
zPEAL=np.empty(150,dtype=int)
zPEALUP=np.empty(150,dtype=int)
zSLIPCUT=np.empty(150,dtype=int)
zSLIPCUTUP=np.empty(150,dtype=int)


aCUT=dataCUTmatrix[:,12]
bCUT=dataCUTmatrix[:,13]
cCUT=dataCUTmatrix[:,14]

for i in range(150):
  zCUT[i]=(aCUT[i]+bCUT[i]+cCUT[i])/3

aINFARO=dataINFAROmatrix[:,12]
bINFARO=dataINFAROmatrix[:,13]
cINFARO=dataINFAROmatrix[:,14]

for i in range(150):
  zINFARO[i]=(aINFARO[i]+bINFARO[i]+cINFARO[i])/3

aINFAROUP=dataINFAROUPmatrix[:,12]
bINFAROUP=dataINFAROUPmatrix[:,13]
cINFAROUP=dataINFAROUPmatrix[:,14]

for i in range(150):
  zINFAROUP[i]=(aINFAROUP[i]+bINFAROUP[i]+cINFAROUP[i])/3

aOUTFARO=dataOUTFAROmatrix[:,12]
bOUTFARO=dataOUTFAROmatrix[:,13]
cOUTFARO=dataOUTFAROmatrix[:,14]

for i in range(150):
  zOUTFARO[i]=(aOUTFARO[i]+bOUTFARO[i]+cOUTFARO[i])/3

aOUTFAROUP=dataOUTFAROUPmatrix[:,12]
bOUTFAROUP=dataOUTFAROUPmatrix[:,13]
cOUTFAROUP=dataOUTFAROUPmatrix[:,14]

for i in range(150):
  zOUTFAROUP[i]=(aOUTFAROUP[i]+bOUTFAROUP[i]+cOUTFAROUP[i])/3

aPEAL=dataPEALmatrix[:,12]
bPEAL=dataPEALmatrix[:,13]
cPEAL=dataPEALmatrix[:,14]

for i in range(150):
  zPEAL[i]=(aPEAL[i]+bPEAL[i]+cPEAL[i])/3

aPEALUP=dataPEALUPmatrix[:,12]
bPEALUP=dataPEALUPmatrix[:,13]
cPEALUP=dataPEALUPmatrix[:,14]

for i in range(150):
  zPEALUP[i]=(aPEALUP[i]+bPEALUP[i]+cPEALUP[i])/3

aSLIPCUT=dataSLIPCUTmatrix[:,12]
bSLIPCUT=dataSLIPCUTmatrix[:,13]
cSLIPCUT=dataSLIPCUTmatrix[:,14]

for i in range(150):
  zSLIPCUT[i]=(aSLIPCUT[i]+bSLIPCUT[i]+cSLIPCUT[i])/3

aSLIPCUTUP=dataSLIPCUTUPmatrix[:,12]
bSLIPCUTUP=dataSLIPCUTUPmatrix[:,13]
cSLIPCUTUP=dataSLIPCUTUPmatrix[:,14]

for i in range(150):
  zSLIPCUTUP[i]=(aSLIPCUTUP[i]+bSLIPCUTUP[i]+cSLIPCUTUP[i])/3

plt.figure(figsize=(12,5))
plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=32 || "SEQUENCE-HAMMING METRIC"')
plt.plot(y, zCUT, label="CUT")
plt.plot(y, zINFARO, label="INFARO")
plt.plot(y, zINFAROUP, label="INFAROUP")
plt.plot(y, zOUTFARO, label="OUTFARO")
plt.plot(y, zOUTFAROUP, label="OUTFAROUP")
plt.plot(y, zPEAL, label="PEAL")
plt.plot(y, zPEALUP, label="PEALUP")
plt.plot(y, zSLIPCUT, label="SLIPCUT")
plt.plot(y, zSLIPCUTUP, label="SLIPCUTUP")
plt.legend()
plt.show()

# %%
#@title
dataCUT_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/CUTTING-INSERTION.csv")
dataCUT_INSERTmatrix=dataCUT_INSERT.to_numpy()

dataCUT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/CUTTING-INTERCALATION.csv")
dataCUT_INTERCALmatrix=dataCUT_INTERCAL.to_numpy()

dataCUT_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/CUTTING-INVERSION.csv")
dataCUT_INVERTmatrix =dataCUT_INVERT.to_numpy()

dataINSERT_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INSERTION-CUTTING.csv")
dataINSERT_CUTmatrix =dataINSERT_CUT.to_numpy()

dataINSERT_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INSERTION-INVERSION.csv")
dataINSERT_INVERTmatrix =dataINSERT_INVERT.to_numpy()

dataINSERT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INSERTION-INTERCALATION.csv")
dataINSERT_INTERCALmatrix =dataINSERT_INTERCAL.to_numpy()

dataINVERT_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INVERSION-CUTTING.csv")
dataINVERT_CUTmatrix =dataINVERT_CUT.to_numpy()

dataINVERT_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INVERSION-INSERTION.csv")
dataINVERT_INSERTmatrix =dataINVERT_INSERT.to_numpy()

dataINVERT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INVERSION-INTERCALATION.csv")
dataINVERT_INTERCALmatrix =dataINVERT_INTERCAL.to_numpy()

dataINTERCAL_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INTERCALATION-CUTTING.csv")
dataINTERCAL_CUTmatrix =dataINTERCAL_CUT.to_numpy()

dataINTERCAL_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INTERCALATION-INVERSION.csv")
dataINTERCAL_INVERTmatrix =dataINTERCAL_INVERT.to_numpy()

dataINTERCAL_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE/INTERCALATION-INSERTION.csv")
dataINTERCAL_INSERTmatrix =dataINTERCAL_INSERT.to_numpy()

# %%
#@title


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,0]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,1]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,2]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,0]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,1]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,2]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,0]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,1]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,2]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,0]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,1]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,2]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,0]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,1]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,2]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,0]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,1]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,2]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,0]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,1]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,2]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,0]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,1]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,2]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,0]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,1]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,2]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,0]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,1]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,0]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,1]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,0]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,1]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=2 || "SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()



zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,3]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,4]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,5]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,3]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,4]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,5]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,3]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,4]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,5]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,3]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,4]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,5]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,3]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,4]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,5]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,3]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,4]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,5]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,3]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,4]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,5]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,3]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,4]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,5]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,3]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,4]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,5]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,3]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,4]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,3]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,4]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,3]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,4]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=4 || "SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,6]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,7]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,8]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,6]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,7]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,8]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,6]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,7]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,8]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,6]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,7]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,8]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,6]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,7]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,8]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,6]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,7]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,8]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,6]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,7]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,8]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,6]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,7]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,8]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,6]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,7]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,8]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,6]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,7]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,6]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,7]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,6]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,7]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=8 || "SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,9]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,10]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,11]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,9]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,10]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,11]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,9]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,10]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,11]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,9]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,10]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,11]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,9]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,10]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,11]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,9]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,10]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,11]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,9]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,10]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,11]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,9]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,10]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,11]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,9]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,10]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,11]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,9]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,10]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,9]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,10]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,9]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,10]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=16 || "SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()



zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,10]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,11]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,12]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,10]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,11]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,12]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,10]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,11]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,12]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,10]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,11]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,12]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,10]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,11]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,12]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,10]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,11]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,12]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,10]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,11]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,12]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,10]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,11]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,12]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,10]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,11]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,12]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,10]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,11]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,10]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,11]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,10]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,11]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=32 || "SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()

# %%
#@title

dataCUT_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/CUTTING-INSERTION.csv")
dataCUT_INSERTmatrix=dataCUT_INSERT.to_numpy()

dataCUT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/CUTTING-INTERCALATION.csv")
dataCUT_INTERCALmatrix=dataCUT_INTERCAL.to_numpy()

dataCUT_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/CUTTING-INVERSION.csv")
dataCUT_INVERTmatrix =dataCUT_INVERT.to_numpy()

dataINSERT_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INSERTION-CUTTING.csv")
dataINSERT_CUTmatrix =dataINSERT_CUT.to_numpy()

dataINSERT_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INSERTION-INVERSION.csv")
dataINSERT_INVERTmatrix =dataINSERT_INVERT.to_numpy()

dataINSERT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INSERTION-INTERCALATION.csv")
dataINSERT_INTERCALmatrix =dataINSERT_INTERCAL.to_numpy()

dataINVERT_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INVERSION-CUTTING.csv")
dataINVERT_CUTmatrix =dataINVERT_CUT.to_numpy()

dataINVERT_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INVERSION-INSERTION.csv")
dataINVERT_INSERTmatrix =dataINVERT_INSERT.to_numpy()

dataINVERT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INVERSION-INTERCALATION.csv")
dataINVERT_INTERCALmatrix =dataINVERT_INTERCAL.to_numpy()

dataINTERCAL_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INTERCALATION-CUTTING.csv")
dataINTERCAL_CUTmatrix =dataINTERCAL_CUT.to_numpy()

dataINTERCAL_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INTERCALATION-INVERSION.csv")
dataINTERCAL_INVERTmatrix =dataINTERCAL_INVERT.to_numpy()

dataINTERCAL_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/HAMMING/INTERCALATION-INSERTION.csv")
dataINTERCAL_INSERTmatrix =dataINTERCAL_INSERT.to_numpy()

# %%
#@title
zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,0]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,1]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,2]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,0]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,1]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,2]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,0]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,1]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,2]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,0]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,1]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,2]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,0]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,1]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,2]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,0]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,1]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,2]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,0]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,1]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,2]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,0]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,1]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,2]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,0]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,1]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,2]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,0]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,1]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,0]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,1]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,0]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,1]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=2 || "HAMMING METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()



zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,3]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,4]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,5]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,3]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,4]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,5]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,3]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,4]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,5]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,3]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,4]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,5]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,3]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,4]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,5]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,3]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,4]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,5]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,3]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,4]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,5]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,3]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,4]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,5]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,3]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,4]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,5]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,3]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,4]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,3]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,4]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,3]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,4]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=4 || "HAMMING METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,6]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,7]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,8]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,6]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,7]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,8]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,6]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,7]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,8]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,6]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,7]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,8]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,6]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,7]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,8]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,6]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,7]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,8]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,6]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,7]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,8]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,6]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,7]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,8]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,6]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,7]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,8]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,6]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,7]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,6]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,7]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,6]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,7]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=8 || "HAMMING METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,9]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,10]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,11]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,9]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,10]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,11]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,9]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,10]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,11]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,9]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,10]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,11]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,9]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,10]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,11]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,9]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,10]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,11]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,9]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,10]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,11]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,9]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,10]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,11]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,9]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,10]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,11]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,9]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,10]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,9]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,10]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,9]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,10]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=16 || "HAMMING METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()



zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,10]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,11]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,12]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,10]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,11]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,12]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,10]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,11]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,12]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,10]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,11]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,12]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,10]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,11]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,12]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,10]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,11]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,12]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,10]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,11]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,12]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,10]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,11]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,12]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,10]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,11]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,12]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,10]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,11]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,10]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,11]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,10]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,11]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=32 || "HAMMING METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()

# %%
#@title
dataCUT_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/CUTTING-INSERTION.csv")
dataCUT_INSERTmatrix=dataCUT_INSERT.to_numpy()

dataCUT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/CUTTING-INTERCALATION.csv")
dataCUT_INTERCALmatrix=dataCUT_INTERCAL.to_numpy()

dataCUT_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/CUTTING-INVERSION.csv")
dataCUT_INVERTmatrix =dataCUT_INVERT.to_numpy()

dataINSERT_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INSERTION-CUTTING.csv")
dataINSERT_CUTmatrix =dataINSERT_CUT.to_numpy()

dataINSERT_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INSERTION-INVERSION.csv")
dataINSERT_INVERTmatrix =dataINSERT_INVERT.to_numpy()

dataINSERT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INSERTION-INTERCALATION.csv")
dataINSERT_INTERCALmatrix =dataINSERT_INTERCAL.to_numpy()

dataINVERT_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INVERSION-CUTTING.csv")
dataINVERT_CUTmatrix =dataINVERT_CUT.to_numpy()

dataINVERT_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INVERSION-INSERTION.csv")
dataINVERT_INSERTmatrix =dataINVERT_INSERT.to_numpy()

dataINVERT_INTERCAL = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INVERSION-INTERCALATION.csv")
dataINVERT_INTERCALmatrix =dataINVERT_INTERCAL.to_numpy()

dataINTERCAL_CUT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INTERCALATION-CUTTING.csv")
dataINTERCAL_CUTmatrix =dataINTERCAL_CUT.to_numpy()

dataINTERCAL_INVERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INTERCALATION-INVERSION.csv")
dataINTERCAL_INVERTmatrix =dataINTERCAL_INVERT.to_numpy()

dataINTERCAL_INSERT = pd.read_csv("../content/drive/My Drive/GeneticProgramming/FIRST_EXP/SEQUENCE-HAMMING/INTERCALATION-INSERTION.csv")
dataINTERCAL_INSERTmatrix =dataINTERCAL_INSERT.to_numpy()

# %%
#@title

zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,0]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,1]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,2]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,0]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,1]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,2]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,0]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,1]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,2]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,0]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,1]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,2]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,0]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,1]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,2]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,0]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,1]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,2]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,0]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,1]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,2]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,0]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,1]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,2]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,0]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,1]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,2]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,0]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,1]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,0]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,1]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,0]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,1]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,2]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=2 || "HAMMING-SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()



zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,3]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,4]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,5]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,3]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,4]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,5]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,3]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,4]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,5]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,3]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,4]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,5]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,3]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,4]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,5]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,3]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,4]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,5]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,3]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,4]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,5]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,3]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,4]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,5]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,3]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,4]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,5]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,3]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,4]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,3]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,4]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,3]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,4]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,5]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=4 || "HAMMING-SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,6]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,7]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,8]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,6]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,7]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,8]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,6]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,7]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,8]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,6]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,7]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,8]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,6]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,7]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,8]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,6]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,7]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,8]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,6]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,7]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,8]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,6]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,7]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,8]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,6]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,7]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,8]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,6]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,7]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,6]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,7]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,6]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,7]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,8]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=8 || "HAMMING-SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()


zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,9]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,10]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,11]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,9]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,10]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,11]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,9]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,10]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,11]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,9]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,10]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,11]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,9]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,10]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,11]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,9]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,10]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,11]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,9]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,10]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,11]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,9]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,10]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,11]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,9]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,10]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,11]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,9]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,10]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,9]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,10]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,9]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,10]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,11]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=16 || "HAMMING-SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()



zdataCUT_INSERTmatrix=np.empty(150,dtype=int)
zdataCUT_INTERCALmatrix=np.empty(150,dtype=int)
zdataCUT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_CUTmatrix=np.empty(150,dtype=int)
zdataINSERT_INVERTmatrix=np.empty(150,dtype=int)
zdataINSERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINVERT_CUTmatrix=np.empty(150,dtype=int)
zdataINVERT_INSERTmatrix=np.empty(150,dtype=int)
zdataINVERT_INTERCALmatrix=np.empty(150,dtype=int)
zdataINTERCAL_CUTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INVERTmatrix=np.empty(150,dtype=int)
zdataINTERCAL_INSERTmatrix=np.empty(150,dtype=int)



adataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,10]
bdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,11]
cdataCUT_INSERTmatrix=dataCUT_INSERTmatrix[:,12]

for i in range(150):
  zdataCUT_INSERTmatrix[i]=(adataCUT_INSERTmatrix[i]+bdataCUT_INSERTmatrix[i]+cdataCUT_INSERTmatrix[i])/3

adataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,10]
bdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,11]
cdataCUT_INTERCALmatrix=dataCUT_INTERCALmatrix[:,12]

for i in range(150):
  zdataCUT_INTERCALmatrix[i]=(adataCUT_INTERCALmatrix[i]+bdataCUT_INTERCALmatrix[i]+cdataCUT_INTERCALmatrix[i])/3

adataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,10]
bdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,11]
cdataCUT_INVERTmatrix=dataCUT_INVERTmatrix[:,12]

for i in range(150):
  zdataCUT_INVERTmatrix[i]=(adataCUT_INVERTmatrix[i]+bdataCUT_INVERTmatrix[i]+cdataCUT_INVERTmatrix[i])/3

adataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,10]
bdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,11]
cdataINSERT_CUTmatrix=dataINSERT_CUTmatrix[:,12]

for i in range(150):
  zdataINSERT_CUTmatrix[i]=(adataINSERT_CUTmatrix[i]+bdataINSERT_CUTmatrix[i]+cdataINSERT_CUTmatrix[i])/3

adataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,10]
bdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,11]
cdataINSERT_INVERTmatrix=dataINSERT_INVERTmatrix[:,12]

for i in range(150):
  zdataINSERT_INVERTmatrix[i]=(adataINSERT_INVERTmatrix[i]+bdataINSERT_INVERTmatrix[i]+cdataINSERT_INVERTmatrix[i])/3

adataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,10]
bdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,11]
cdataINSERT_INTERCALmatrix=dataINSERT_INTERCALmatrix[:,12]

for i in range(150):
  zdataINSERT_INTERCALmatrix[i]=(adataINSERT_INTERCALmatrix[i]+bdataINSERT_INTERCALmatrix[i]+cdataINSERT_INTERCALmatrix[i])/3

adataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,10]
bdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,11]
cdataINVERT_CUTmatrix=dataINVERT_CUTmatrix[:,12]

for i in range(150):
  zdataINVERT_CUTmatrix[i]=(adataINVERT_CUTmatrix[i]+bdataINVERT_CUTmatrix[i]+cdataINVERT_CUTmatrix[i])/3

adataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,10]
bdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,11]
cdataINVERT_INSERTmatrix=dataINVERT_INSERTmatrix[:,12]

for i in range(150):
  zdataINVERT_INSERTmatrix[i]=(adataINVERT_INSERTmatrix[i]+bdataINVERT_INSERTmatrix[i]+cdataINVERT_INSERTmatrix[i])/3

adataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,10]
bdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,11]
cdataINVERT_INTERCALmatrix=dataINVERT_INTERCALmatrix[:,12]

for i in range(150):
  zdataINVERT_INTERCALmatrix[i]=(adataINVERT_INTERCALmatrix[i]+bdataINVERT_INTERCALmatrix[i]+cdataINVERT_INTERCALmatrix[i])/3


adataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,10]
bdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,11]
cdataINTERCAL_CUTmatrix=dataINTERCAL_CUTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_CUTmatrix[i]=(adataINTERCAL_CUTmatrix[i]+bdataINTERCAL_CUTmatrix[i]+cdataINTERCAL_CUTmatrix[i])/3

adataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,10]
bdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,11]
cdataINTERCAL_INVERTmatrix=dataINTERCAL_INVERTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_INVERTmatrix[i]=(adataINTERCAL_INVERTmatrix[i]+bdataINTERCAL_INVERTmatrix[i]+cdataINTERCAL_INVERTmatrix[i])/3

adataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,10]
bdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,11]
cdataINTERCAL_INSERTmatrix=dataINTERCAL_INSERTmatrix[:,12]

for i in range(150):
  zdataINTERCAL_INSERTmatrix[i]=(adataINTERCAL_INSERTmatrix[i]+bdataINTERCAL_INSERTmatrix[i]+cdataINTERCAL_INSERTmatrix[i])/3

plt.figure(figsize=(12,5))

plt.grid(b=True, color='DarkTurquoise', alpha=0.2, linestyle=':', linewidth=2)
plt.style.use('dark_background')
plt.xlabel('GENERATIONS', fontsize=15)
plt.ylabel('POINTS', fontsize=15)
plt.title('AVERAGE DATA (FROM 3 EXECUTIONS) N=32 || "HAMMING-SEQUENCE METRIC"')
plt.plot(y,zdataINSERT_CUTmatrix, color="purple", label="INSERT CUT")
plt.plot(y,zdataCUT_INSERTmatrix, '--', color="purple", label="CUT INSERTION")

plt.plot(y,zdataCUT_INTERCALmatrix, color="red", label="CUT INTERCALATION")
plt.plot(y,zdataINTERCAL_CUTmatrix, '--', color="red", label="INTERCALATION CUT")

plt.plot(y,zdataINTERCAL_CUTmatrix, color="blue", label="CUT INVERTION")
plt.plot(y,zdataCUT_INVERTmatrix, '--', color="blue", label="INVERT CUT")

plt.plot(y,zdataINSERT_INVERTmatrix, color="yellow", label="INSERT INVERTION")
plt.plot(y,zdataINVERT_INSERTmatrix, '--', color="yellow", label="INVERT INSERTION")

plt.plot(y,zdataINSERT_INTERCALmatrix, color="brown", label="INSERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INSERTmatrix, '--', color="brown", label="INTERCALATION INSERTION")

plt.plot(y,zdataINVERT_INTERCALmatrix, color="green", label="INVERT INTERCALATION")
plt.plot(y,zdataINTERCAL_INVERTmatrix, '--', color="green",  label="INTERCALATION INVERTION")

plt.legend()
plt.show()
